# %% [markdown]
# # 3.2 LEDs
#  ![image.png](data:image/png;base64,...)
#
# # V = R * I

# %%
va = 3.3-2.0
ia = 0.01
ra = va/ia
print(ra)
# Out:
# 129.99999999999997

# %%
vb = 5.0-1.7
ib = 0.012
rb = vb/ib
print(rb)
# Out:
# 275.0

# %%
vc = 3.3-2.2
ic = 0.011
rc = vc/ic
print(rc)
# Out:
# 99.99999999999997

# %% [markdown]
# # 3.4 Transistores
#
# ![image.png](data:image/png;base64,...
# )

# %%
Vb = 3.3
Vbe = 0.8
Ic = 0.05
ganho = 100
Rbase = (Vb - Vbe)/(10*(Ic/ganho))
print("Resistor na base e':", Rbase)
# Out:
# Resistor na base e': 500.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Vled = 2.0 # Volts
VR1 = 3.0  #Volts
Ie = 0.010  #Amperè
R1 = VR1/Ie #Ohms
print("Resistor 1 é:", R1)
# Out:
# Resistor 1 é: 300.0

# %%
Vb = 3.3
Vbe = 0.8
Ic = 0.05
ganho = 100
Rbase = (Vb - Vbe)/(10*(Ic/ganho))
print("Resistor na base e':", Rbase)
